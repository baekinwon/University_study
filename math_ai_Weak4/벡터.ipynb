# %%
import numpy as np

a = 2
x = np.array([1,2,3])

print(a * x)
# Out:
# [2 4 6]

# %%
x = np.array([1,2,3])
y = np.array([4,5,6])

print(x+y)
# Out:
# [5 7 9]

# %%
x = np.array([1,2,3,4,5])
y = np.array([4,5,6])

print(x+y)

# %%
x = [1, 2, 3, 4, 5]
y = [3, 4, 5]
print(x+y)
# Out:
# [1, 2, 3, 4, 5, 3, 4, 5]

# %%
x = np.array([1,2,3])
y = np.array([4,5,6])
print(x-y)
# Out:
# [-3 -3 -3]

# %%
x = np.array([1,2,3])
y = np.array([4,5,6])
print(x*y)
# Out:
# [ 4 10 18]
